# %%
from DataProcessing import Readout
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['font.family'] = 'Times New Roman'
rcParams['mathtext.fontset'] = 'stix'
rcParams['axes.unicode_minus'] = False
rcParams.update({
	'font.size': 14,
	'axes.titlesize': 14,
	'axes.labelsize': 14,
	'xtick.labelsize': 14,
	'ytick.labelsize': 14,
	'legend.fontsize': 14,
	'figure.titlesize': 14,
	'legend.frameon': False,
})

# %%
from pathlib import Path

data_dir = Path(
    f"/run/user/1000/gvfs/"
    "smb-share:server=lsa-graithel-win.turbo.storage.umich.edu,share=lsa-graithel"
    "/migratedData/Rydberg_QIS/data"
)

print("Exists:", data_dir.exists())

for p in data_dir.iterdir():
    print(p.name)
# Out:
# Exists: True
# Readout_template.ipynb
# 2025
# 2026
# 1064 beam size
# 2026.02.05_RC-test.ipynb
# 4f_MOT_260402_225827_725
# Thumbs.db
# 2026.1.27.ipynb
# TIP-MOT distance.pptx
# Shawdow_Image

# %%
# root_dir = "X:/migratedData/Rydberg_QIS/data"
root_dir = f"/run/user/1000/gvfs/smb-share:server=lsa-graithel-win.turbo.storage.umich.edu,share=lsa-graithel/migratedData/Rydberg_QIS/data"   # Linux
x,y,z,notes = Readout.read_saved_csv_by_id(root_dir=root_dir, date="2026/03/08", plot_id=4)

# %%
plt.pcolormesh(x,y,z.T)
plt.xlabel(notes["xlabel"])
plt.ylabel(notes["ylabel"])
cbar = plt.colorbar()
cbar.set_label(notes["zlabel"])

# %%
print(notes)
# Out:
# {'Date': '2025/12/11', 'ID': '8', 'Data hash': '1e3e35063967b7beba95640e16ac472764c4c769469c9963038d867c6990d547', 'xlabel': 'Voltage 0 (V)', 'ylabel': '480 laser frequency (kHz)', 'zlabel': 'Average number of counts', 'x range': '-4.8 to 5.2, total 21 points', 'y range': '0.0 to 102168.0, total 100 points', 'Notes': {'gate_width': '1.5e-05', 'gate_delay': '3e-06', 'bnc575 T0': '1.00e-03', 'bnc575 pulses': "[['A', 0.0009, 0, 'TTL'], ['B', 1e-05, 0.000905, 15], ['C', 1e-05, 0.000905, 'TTL'], ['D', 2e-05, 0.000915, 8]]"}}
