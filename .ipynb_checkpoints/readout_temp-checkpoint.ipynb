# %%
from DataProcessing import Readout
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['font.family'] = 'Times New Roman'
rcParams['mathtext.fontset'] = 'stix'
rcParams['axes.unicode_minus'] = False
rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 14,
    'legend.frameon': False,
})

# %%
#root_dir = \"X:/migratedData/Rydberg_QIS/data\"
root_dir = f\"/run/user/1000/gvfs/smb-share:server=lsa-graithel-win.turbo.storage.umich.edu,share=lsa-graithel/migratedData//Rydberg_QIS/data\"   
# Linux
x,y,z,notes = Readout.read_saved_csv_by_id(root_dir = root_dir, date = \"2026/03/08\", plot_id = 4)
# Out:
#   Cell In[3], line 2
#     root_dir = f\"/run/user/1000/gvfs/smb-share:server=lsa-graithel-win.turbo.storage.umich.edu,share=lsa-graithel/migratedData//Rydberg_QIS/data\"
#                  ^
# SyntaxError: unexpected character after line continuation character
