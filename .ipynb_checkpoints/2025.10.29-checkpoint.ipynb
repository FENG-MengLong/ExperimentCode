# %% [markdown]
# ## Packages

# %%
from Equipments import BNC575
from Equipments import Weeder
from Equipments import SR400
from Equipments import MCBOX
from Equipments import Andor
import numpy as np
import matplotlib.pyplot as plt
import pyvisa
import time

# %% [markdown]
# ## Initialize

# %%
rm = pyvisa.ResourceManager()
print(rm.list_resources())
# Out:
# ('TCPIP0::141.211.97.110::inst0::INSTR', 'ASRL1::INSTR', 'ASRL2::INSTR', 'ASRL3::INSTR', 'ASRL4::INSTR', 'ASRL5::INSTR', 'ASRL6::INSTR', 'ASRL7::INSTR', 'GPIB0::9::INSTR', 'GPIB0::23::INSTR')

# %%
# sr400 = SR400.SR400('GPIB0::23::INSTR')
sr400 = SR400.SR400('GPIB0::23::INSTR',timeout=1000)

# %%
bnc575 = BNC575.BNC575("GPIB0::9::INSTR")

# %%
# set the pulse sequence
#                   channel width  delay
# pulse_arrangement = [["A", 9000e-6, 0], # MOT
#                      ["B", 4e-6, 9001e-6], # 480 EXC
#                      ["C", 4e-6, 9001e-6], # 780 EXC
#                      ["G", 50e-6, 9006e-6], # SR400 trigger, the width is not the gate width, it is just a trigger, it can also be scanned. To realize, scan it in the loop
#                     ]

pulse_arrangement = [["B",0.5,0],]

# photon counter gate width
gate_width = 0.6

# period of a sequence
T = 2

# number of the sequence cycle
cycle_number = 10

# frequency per motor step
freq_step = 78.5 #KHz

# motor step range
motor_step_range = np.arange(0,101)
relative_freq_range = freq_step * motor_step_range

# electrode setting
board_num = 0
channels = 10
bipolar = True
voltage_range = np.linspace(-5,5,101)

# %%
sr400.counter_set(count_mode = "INDEPENDENT", count_preset = 1, count_period_num=cycle_number, dwell=0, sourceA="INPUT1",sourceB="INPUT2", gate_A_mode="FIXED", gate_A_delay=0,
                gate_A_width=gate_width,gate_B_mode="CW")
# Out:
# ---------------------------------------
# The photon counter is now set to:
#
# Counting Mode: INDEPENDENT
# T Input: 10MHz
# T Preset: 1.0s
# Period number: 10
# Dwell time: External
# Counter A source: INPUT1
# Counter B source: INPUT2
#
# The gate A is set to:
#
# Delay: 0.000E-6
# Width: 600.0E-3
#
#
# The gate B is set to: CW
# ---------------------------------------

# %%
bnc575.disable_all()

# %%
bnc575.disarm_all()
bnc575.clock_set(period=T, mode="BURST", burstctr=cycle_number)
# bnc575.clock_set(period=T,mode="CONTINUOUS")

# bnc575.channel_set(channel="H",width=pulse_arrangement[0][1],delay=pulse_arrangement[0][2], MUX="00001111")

for idn, pulse in enumerate(pulse_arrangement):
    print(pulse[1])
    bnc575.channel_set(channel=pulse[0],width=pulse[1],delay=pulse[2])
# Out:
# ---------------------------------------
# The global clock is set to:
# Mode: BURS
# Period: 2.00e+00s
# Pulses number: 10
# ---------------------------------------
# 0.5
# ---------------------------------------
# The channel B is set to:
# Width: 5.0000e-01s
# Delay: 0.0000e+00s
# Synchronize to: T0
# Output timers:
# HGFEDCBA
# 00000010
# ---------------------------------------

# %%
bnc575.start_pulses()

# %%
bg = np.mean(sr400.read_entire_counts(counter="A",length = cycle_number))
print(bg)
# Out:
# One entire measurement is done, the last count is 14
# [9, 17, 7, 5, 4, 11, 6, 8, 35, 14]
# 11.6

# %%
sig = np.mean(sr400.read_entire_counts(counter="A",length = cycle_number))
print(sig)
print(bg)
# Out:
# One entire measurement is done, the last count is 13
# [14, 16, 12, 5, 18, 32, 9, 11, 14, 20, 26, 14, 30, 23, 8, 18, 25, 13, 19, 23, 31, 12, 21, 30, 5, 24, 22, 22, 17, 39, 13, 44, 18, 21, 29, 8, 22, 36, 24, 22, 5, 44, 3, 21, 20, 28, 18, 34, 36, 14, 8, 14, 41, 5, 40, 15, 36, 33, 35, 32, 23, 28, 8, 30, 14, 24, 8, 17, 36, 7, 12, 17, 19, 21, 23, 17, 12, 23, 27, 14, 12, 11, 15, 35, 20, 35, 12, 25, 11, 10, 28, 29, 40, 28, 19, 24, 18, 38, 23, 13]
# 21.18
# 10.48

# %%
bnc575.disarm_all()

# %%
sr400.count_reset()
