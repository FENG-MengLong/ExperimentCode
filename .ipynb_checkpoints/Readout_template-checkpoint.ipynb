# %%
from DataProcessing import Readout
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['font.family'] = 'Times New Roman'
rcParams['mathtext.fontset'] = 'stix'
rcParams['axes.unicode_minus'] = False
rcParams.update({
	'font.size': 14,
	'axes.titlesize': 14,
	'axes.labelsize': 14,
	'xtick.labelsize': 14,
	'ytick.labelsize': 14,
	'legend.fontsize': 14,
	'figure.titlesize': 14,
	'legend.frameon': False,
})

# %%
root_dir = "X:/migratedData/Rydberg_QIS/data"
x,y,z,notes = Readout.read_saved_csv_by_id(root_dir=root_dir, date="2025/12/16", plot_id=9)

# %%
plt.plot(x,z)

# %%
plt.pcolormesh(x,y,z.T,vmin=0, vmax=3)
plt.xlabel(notes["xlabel"])
plt.ylabel(notes["ylabel"])
cbar = plt.colorbar()
cbar.set_label(notes["zlabel"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.pcolormesh(x,y,z.T,vmin=0, vmax=3)
#       2 plt.xlabel(notes["xlabel"])
#       3 plt.ylabel(notes["ylabel"])
#
# File c:\Anaconda\Lib\site-packages\matplotlib\pyplot.py:3493, in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    3480 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    3481 def pcolormesh(
#    3482     *args: ArrayLike,
#    (...)
#    3491     **kwargs,
#    3492 ) -> QuadMesh:
# -> 3493     __ret = gca().pcolormesh(
#    3494         *args,
#    3495         alpha=alpha,
#    3496         norm=norm,
#    3497         cmap=cmap,
#    3498         vmin=vmin,
#    3499         vmax=vmax,
#    3500         shading=shading,
#    3501         antialiased=antialiased,
#    3502         **({"data": data} if data is not None else {}),
#    3503         **kwargs,
#    3504     )
#    3505     sci(__ret)
#    3506     return __ret
#
# File c:\Anaconda\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File c:\Anaconda\Lib\site-packages\matplotlib\axes\_axes.py:6292, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6289 shading = shading.lower()
#    6290 kwargs.setdefault('edgecolors', 'none')
# -> 6292 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6293                                     shading=shading, kwargs=kwargs)
#    6294 coords = np.stack([X, Y], axis=-1)
#    6296 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File c:\Anaconda\Lib\site-packages\matplotlib\axes\_axes.py:5815, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5810         if np.ma.is_masked(X) or np.ma.is_masked(Y):
#    5811             raise ValueError(
#    5812                 'x and y arguments to pcolormesh cannot have '
#    5813                 'non-finite values or be of type '
#    5814                 'numpy.ma.MaskedArray with masked values')
# -> 5815     nrows, ncols = C.shape[:2]
#    5816 else:
#    5817     raise _api.nargs_error(funcname, takes="1 or 3", given=len(args))
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
print(notes)
# Out:
# {'Date': '2025/12/11', 'ID': '8', 'Data hash': '1e3e35063967b7beba95640e16ac472764c4c769469c9963038d867c6990d547', 'xlabel': 'Voltage 0 (V)', 'ylabel': '480 laser frequency (kHz)', 'zlabel': 'Average number of counts', 'x range': '-4.8 to 5.2, total 21 points', 'y range': '0.0 to 102168.0, total 100 points', 'Notes': {'gate_width': '1.5e-05', 'gate_delay': '3e-06', 'bnc575 T0': '1.00e-03', 'bnc575 pulses': "[['A', 0.0009, 0, 'TTL'], ['B', 1e-05, 0.000905, 15], ['C', 1e-05, 0.000905, 'TTL'], ['D', 2e-05, 0.000915, 8]]"}}
