# %%
from Equipments import BNC575
from Equipments import Weeder
from Equipments import SR400
from Equipments import MCBOX
from Equipments import Andor
import numpy as np
import matplotlib.pyplot as plt
import pyvisa
import time

# %%
from DataProcessing.Plot import PlotSaver

# %%
ps = PlotSaver("D:\\testsave")

# %%
x = np.linspace(0, 10, 10)       # x-grid edges (11 for 10 cells)
y = np.linspace(0, 5, 6)         # y-grid edges (6 for 5 cells)
X, Y = np.meshgrid(x, y)         # create grid
Z = np.random.rand(6, 10)

# %%
ps.Plot3D(x,y,Z)

# %%
ps.Plot2D(x,y,Z,y_index=[2,5])

# %%
x = np.linspace(1,10,10)
y = 1
z = [1,2,3,4,5,6,7,8,9,0]

# %%
ps.Plot2D(x,y,z,y_index=[2,5])

# %%
rm = pyvisa.ResourceManager()
print(rm.list_resources())
# Out:
# ('TCPIP0::141.211.97.110::inst0::INSTR', 'ASRL1::INSTR', 'ASRL2::INSTR', 'ASRL3::INSTR', 'ASRL4::INSTR', 'ASRL5::INSTR', 'ASRL6::INSTR', 'ASRL7::INSTR', 'ASRL9::INSTR')

# %%
bnc575 = BNC575.BNC575("GPIB0::9::INSTR")
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bnc575 = BNC575.BNC575("GPIB0::9::INSTR")
#
# File ~\Documents\Python\Experiments\Equipments\BNC575.py:6, in BNC575.__init__(self, visa_name, timeout)
#       4 def __init__(self, visa_name, timeout = 5000):
#       5     rm = pyvisa.ResourceManager()
# ----> 6     self.pyvisa = rm.open_resource(visa_name)
#       7     self.pyvisa.timeout = timeout
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\highlevel.py:3293, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3287     if not present:
#    3288         raise ValueError(
#    3289             "%r is not a valid attribute for type %s"
#    3290             % (key, res.__class__.__name__)
#    3291         )
# -> 3293 res.open(access_mode, open_timeout)
#    3295 for key, value in kwargs.items():
#    3296     setattr(res, key, value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\resources\resource.py:296, in Resource.open(self, access_mode, open_timeout)
#     294 time.sleep(sleep_time)
#     295 try:
# --> 296     self.clear()
#     297     break
#     298 except errors.VisaIOError as error:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\resources\resource.py:382, in Resource.clear(self)
#     380 def clear(self) -> None:
#     381     """Clear this resource."""
# --> 382     self.visalib.clear(self.session)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\ctwrapper\functions.py:617, in clear(library, session)
#     599 def clear(library, session):
#     600     """Clears a device.
#     601
#     602     Corresponds to viClear function of the VISA library.
#    (...)
#     615
#     616     """
# --> 617     return library.viClear(session)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_BERR (-1073807304): Bus error occurred during transfer.
