# %% [markdown]
# # Initialize the instrument

# %%
from Equipments import BNC575
from Equipments import Weeder
from Equipments import SR400
from Equipments import MCBOX
from Equipments import Andor
import numpy as np
import matplotlib.pyplot as plt
import pyvisa
import time

# %%
from DataProcessing.Plot import PlotSaver

# %%
ps = PlotSaver("X:\\migratedData\\Rydberg_QIS\\data")

# %%
rm = pyvisa.ResourceManager()
print(rm.list_resources())
# Out:
# ('ASRL1::INSTR', 'ASRL2::INSTR', 'ASRL3::INSTR', 'ASRL4::INSTR', 'ASRL5::INSTR', 'ASRL6::INSTR', 'ASRL7::INSTR', 'GPIB0::9::INSTR', 'GPIB0::23::INSTR')

# %%
bnc575 = BNC575.BNC575("GPIB0::9::INSTR")

# %%
sr400 = SR400.SR400('GPIB0::23::INSTR',timeout=1000)

# %%
weeder = Weeder.Weeder("ASRL1::INSTR")

# %%
mcbox = MCBOX.MCBOX(find_device = "USB-3114")
# Out:
# USB-3114 found.
# Board number: 0

# %% [markdown]
# # Define the pulse

# %%
pulse_arrangement = [["A", 900e-6, 0, "TTL"],   # MOT
                     [["B", 10e-6, 5e-6, 15],    # 780 excitation 20dB attenuator connected
                      ["C", 10e-6, 5e-6, "TTL"]],    # 480 exc
                     ["D", 20e-6, 0, 8],        # DEI switch
                    ]
T = 1000e-6

cycle_number = 30
# photon counter gate width
gate_width = 15e-6
gate_delay = 3e-6

# %%
sr400.counter_set(count_mode = "INDEPENDENT", count_preset = 100e-6, count_period_num=cycle_number, dwell=0, sourceA="INPUT1",sourceB="INPUT2", gate_A_mode="FIXED", gate_A_delay=gate_delay,
                gate_A_width=gate_width,gate_B_mode="CW")
# Out:
# ---------------------------------------
# The photon counter is now set to:
#
# Counting Mode: INDEPENDENT
# T Input: 10MHz
# T Preset: 0.0001s
# Period number: 30
# Dwell time: External
# Counter A source: INPUT1
# Counter B source: INPUT2
#
# The gate A is set to:
#
# Delay: 3.000E-6
# Width: 15.00E-6
#
#
# The gate B is set to: CW
# ---------------------------------------

# %%
bnc575.clock_set(period=T,mode="CONTINUOUS")
bnc575.pulse_sequence_setup(pulse_arrangement)
# Out:
# ---------------------------------------
# The global clock is set to:
# Mode: NORM
# Period: 1.00e-03s
# Pulses number: N/A
# ---------------------------------------
# [['A', 0.0009, 0, 'TTL'], ['B', 1e-05, 0.000905, 15], ['C', 1e-05, 0.000905, 'TTL'], ['D', 2e-05, 0.000915, 8]]
# ---------------------------------------
# The channel A is set to:
# Width: 9.0000e-04s
# Delay: 0.0000e+00s
# Synchronize to: T0
# Out: TTL
#
# Output timers:
# HGFEDCBA
# 00000001
# ---------------------------------------
# ---------------------------------------
# The channel B is set to:
# Width: 1.0000e-05s
# Delay: 9.0500e-04s
# Synchronize to: T0
# Out: 15.00
#
# Output timers:
# HGFEDCBA
# 00000010
# ---------------------------------------
# ---------------------------------------
# The channel C is set to:
# Width: 1.0000e-05s
# Delay: 9.0500e-04s
# Synchronize to: T0
# Out: TTL
#
# Output timers:
# HGFEDCBA
# 00000100
# ---------------------------------------
# ---------------------------------------
# The channel D is set to:
# Width: 2.0000e-05s
# Delay: 9.1500e-04s
# Synchronize to: T0
# Out: 8.00
#
# Output timers:
# HGFEDCBA
# 00001000
# ---------------------------------------

# %%
bnc575.start_pulses()

# %% [markdown]
# # Search the resonance

# %%
weeder.position(header = "A", query = True)
# Out:
# 'A3423'

# %%
weeder.move("A", position = 3400, progress = True)
# Out:
# start at 3100 --> 3400.0 --> 3400
# Old position: 3100
# New position: 3400

# %%
weeder.advance(header = "A", num_step = -10)
# Out:
# start at 3360 --> 3350.0 --> 3350
# Old position: 3360
# New position: 3350

# %% [markdown]
# # Stark map

# %% [markdown]
# ## Scan parameters

# %%
center = 3360
stride = 1
half_width = 200


# scan list gneration
x_list = np.arange(2* half_width/stride)

# %%
# everytime go further and go back to release the band tension and gear margin
start_position = center - half_width
weeder.move(header = "A", position = start_position-100)
weeder.move(header = "A", position = start_position)

results = []
s = time.time()
for idx in x_list:
    print(f"now checking step: {idx}", end = "\r", flush=True)
    sr400.count_reset()
    time.sleep(0.1)
    result = np.mean(sr400.read_entire_counts(counter="A",length = cycle_number))
    results.append(result)
    for i in range(stride):
        weeder.step("A","+")
    time.sleep(0.1)
e = time.time()
print(e-s)
# Out:
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# now checking step: 0.0
# One entire measurement is done, the last count is 0
# now checking step: 1.0
# One entire measurement is done, the last count is 0
# now checking step: 2.0
# One entire measurement is done, the last count is 0
# now checking step: 3.0
# One entire measurement is done, the last count is 0
# now checking step: 4.0
# One entire measurement is done, the last count is 0
# now checking step: 5.0
# One entire measurement is done, the last count is 0
# now checking step: 6.0
# One entire measurement is done, the last count is 0
# now checking step: 7.0
# One entire measurement is done, the last count is 0
# now checking step: 8.0
# One entire measurement is done, the last count is 0
# now checking step: 9.0
# One entire measurement is done, the last count is 0
# now checking step: 10.0
# One entire measurement is done, the last count is 0
# now checking step: 11.0
# One entire measurement is done, the last count is 0
# now checking step: 12.0
# One entire measurement is done, the last count is 0
# now checking step: 13.0
# One entire measurement is done, the last count is 2
# now checking step: 14.0
# One entire measurement is done, the last count is 0
# now checking step: 15.0
# One entire measurement is done, the last count is 0
# now checking step: 16.0
# One entire measurement is done, the last count is 0
# now checking step: 17.0
# One entire measurement is done, the last count is 0
# now checking step: 18.0
# One entire measurement is done, the last count is 0
# now checking step: 19.0
# One entire measurement is done, the last count is 0
# now checking step: 20.0
# One entire measurement is done, the last count is 0
# now checking step: 21.0
# One entire measurement is done, the last count is 0
# now checking step: 22.0
# One entire measurement is done, the last count is 0
# now checking step: 23.0
# One entire measurement is done, the last count is 0
# now checking step: 24.0
# One entire measurement is done, the last count is 0
# now checking step: 25.0
# One entire measurement is done, the last count is 0
# now checking step: 26.0
# One entire measurement is done, the last count is 0
# now checking step: 27.0
# One entire measurement is done, the last count is 0
# now checking step: 28.0
# One entire measurement is done, the last count is 0
# now checking step: 29.0
# One entire measurement is done, the last count is 0
# now checking step: 30.0
# One entire measurement is done, the last count is 0
# now checking step: 31.0
# One entire measurement is done, the last count is 0
# now checking step: 32.0
# One entire measurement is done, the last count is 0
# now checking step: 33.0
# One entire measurement is done, the last count is 0
# now checking step: 34.0
# One entire measurement is done, the last count is 0
# now checking step: 35.0
# One entire measurement is done, the last count is 0
# now checking step: 36.0
# One entire measurement is done, the last count is 1
# now checking step: 37.0
# One entire measurement is done, the last count is 0
# now checking step: 38.0
# One entire measurement is done, the last count is 0
# now checking step: 39.0
# One entire measurement is done, the last count is 0
# now checking step: 40.0
# One entire measurement is done, the last count is 0
# now checking step: 41.0
# One entire measurement is done, the last count is 0
# now checking step: 42.0
# One entire measurement is done, the last count is 0
# now checking step: 43.0
# One entire measurement is done, the last count is 0
# now checking step: 44.0
# One entire measurement is done, the last count is 0
# now checking step: 45.0
# One entire measurement is done, the last count is 0
# now checking step: 46.0
# One entire measurement is done, the last count is 0
# now checking step: 47.0
# One entire measurement is done, the last count is 0
# now checking step: 48.0
# One entire measurement is done, the last count is 0
# now checking step: 49.0
# One entire measurement is done, the last count is 0
# now checking step: 50.0
# One entire measurement is done, the last count is 0
# now checking step: 51.0
# One entire measurement is done, the last count is 0
# now checking step: 52.0
# One entire measurement is done, the last count is 0
# now checking step: 53.0
# One entire measurement is done, the last count is 0
# now checking step: 54.0
# One entire measurement is done, the last count is 0
# now checking step: 55.0
# One entire measurement is done, the last count is 0
# now checking step: 56.0
# One entire measurement is done, the last count is 0
# now checking step: 57.0
# One entire measurement is done, the last count is 0
# now checking step: 58.0
# One entire measurement is done, the last count is 0
# now checking step: 59.0
# One entire measurement is done, the last count is 0
# now checking step: 60.0
# One entire measurement is done, the last count is 0
# now checking step: 61.0
# One entire measurement is done, the last count is 0
# now checking step: 62.0
# One entire measurement is done, the last count is 0
# now checking step: 63.0
# One entire measurement is done, the last count is 0
# now checking step: 64.0
# One entire measurement is done, the last count is 0
# now checking step: 65.0
# One entire measurement is done, the last count is 0
# now checking step: 66.0
# One entire measurement is done, the last count is 0
# now checking step: 67.0
# One entire measurement is done, the last count is 0
# now checking step: 68.0
# One entire measurement is done, the last count is 0
# now checking step: 69.0
# One entire measurement is done, the last count is 0
# now checking step: 70.0
# One entire measurement is done, the last count is 0
# now checking step: 71.0
# One entire measurement is done, the last count is 0
# now checking step: 72.0
# One entire measurement is done, the last count is 0
# now checking step: 73.0
# One entire measurement is done, the last count is 0
# now checking step: 74.0
# One entire measurement is done, the last count is 0
# now checking step: 75.0
# One entire measurement is done, the last count is 0
# now checking step: 76.0
# One entire measurement is done, the last count is 0
# now checking step: 77.0
# One entire measurement is done, the last count is 0
# now checking step: 78.0
# One entire measurement is done, the last count is 0
# now checking step: 79.0
# One entire measurement is done, the last count is 0
# now checking step: 80.0
# One entire measurement is done, the last count is 0
# now checking step: 81.0
# One entire measurement is done, the last count is 0
# now checking step: 82.0
# One entire measurement is done, the last count is 0
# now checking step: 83.0
# One entire measurement is done, the last count is 0
# now checking step: 84.0
# One entire measurement is done, the last count is 0
# now checking step: 85.0
# One entire measurement is done, the last count is 0
# now checking step: 86.0
# One entire measurement is done, the last count is 0
# now checking step: 87.0
# One entire measurement is done, the last count is 0
# now checking step: 88.0
# One entire measurement is done, the last count is 0
# now checking step: 89.0
# One entire measurement is done, the last count is 0
# now checking step: 90.0
# One entire measurement is done, the last count is 0
# now checking step: 91.0
# One entire measurement is done, the last count is 0
# now checking step: 92.0
# One entire measurement is done, the last count is 0
# now checking step: 93.0
# One entire measurement is done, the last count is 0
# now checking step: 94.0
# One entire measurement is done, the last count is 0
# now checking step: 95.0
# One entire measurement is done, the last count is 0
# now checking step: 96.0
# One entire measurement is done, the last count is 0
# now checking step: 97.0
# One entire measurement is done, the last count is 0
# now checking step: 98.0
# One entire measurement is done, the last count is 0
# now checking step: 99.0
# One entire measurement is done, the last count is 0
# now checking step: 100.0
# One entire measurement is done, the last count is 0
# now checking step: 101.0
# One entire measurement is done, the last count is 0
# now checking step: 102.0
# One entire measurement is done, the last count is 0
# now checking step: 103.0
# One entire measurement is done, the last count is 0
# now checking step: 104.0
# One entire measurement is done, the last count is 0
# now checking step: 105.0
# One entire measurement is done, the last count is 0
# now checking step: 106.0
# One entire measurement is done, the last count is 0
# now checking step: 107.0
# One entire measurement is done, the last count is 0
# now checking step: 108.0
# One entire measurement is done, the last count is 0
# now checking step: 109.0
# One entire measurement is done, the last count is 0
# now checking step: 110.0
# One entire measurement is done, the last count is 0
# now checking step: 111.0
# One entire measurement is done, the last count is 0
# now checking step: 112.0
# One entire measurement is done, the last count is 0
# now checking step: 113.0
# One entire measurement is done, the last count is 0
# now checking step: 114.0
# One entire measurement is done, the last count is 0
# now checking step: 115.0
# One entire measurement is done, the last count is 0
# now checking step: 116.0
# One entire measurement is done, the last count is 0
# now checking step: 117.0
# One entire measurement is done, the last count is 0
# now checking step: 118.0
# One entire measurement is done, the last count is 0
# now checking step: 119.0
# One entire measurement is done, the last count is 0
# now checking step: 120.0
# One entire measurement is done, the last count is 0
# now checking step: 121.0
# One entire measurement is done, the last count is 0
# now checking step: 122.0
# One entire measurement is done, the last count is 0
# now checking step: 123.0
# One entire measurement is done, the last count is 0
# now checking step: 124.0
# One entire measurement is done, the last count is 0
# now checking step: 125.0
# One entire measurement is done, the last count is 0
# now checking step: 126.0
# One entire measurement is done, the last count is 0
# now checking step: 127.0
# One entire measurement is done, the last count is 0
# now checking step: 128.0
# One entire measurement is done, the last count is 0
# now checking step: 129.0
# One entire measurement is done, the last count is 0
# now checking step: 130.0
# One entire measurement is done, the last count is 0
# now checking step: 131.0
# One entire measurement is done, the last count is 0
# now checking step: 132.0
# One entire measurement is done, the last count is 0
# now checking step: 133.0
# One entire measurement is done, the last count is 0
# now checking step: 134.0
# One entire measurement is done, the last count is 0
# now checking step: 135.0
# One entire measurement is done, the last count is 0
# now checking step: 136.0
# One entire measurement is done, the last count is 0
# now checking step: 137.0
# One entire measurement is done, the last count is 0
# now checking step: 138.0
# One entire measurement is done, the last count is 0
# now checking step: 139.0
# One entire measurement is done, the last count is 0
# now checking step: 140.0
# One entire measurement is done, the last count is 0
# now checking step: 141.0
# One entire measurement is done, the last count is 0
# now checking step: 142.0
# One entire measurement is done, the last count is 0
# now checking step: 143.0
# One entire measurement is done, the last count is 0
# now checking step: 144.0
# One entire measurement is done, the last count is 0
# now checking step: 145.0
# One entire measurement is done, the last count is 0
# now checking step: 146.0
# One entire measurement is done, the last count is 0
# now checking step: 147.0
# One entire measurement is done, the last count is 0
# now checking step: 148.0
# One entire measurement is done, the last count is 0
# now checking step: 149.0
# One entire measurement is done, the last count is 0
# now checking step: 150.0
# One entire measurement is done, the last count is 0
# now checking step: 151.0
# One entire measurement is done, the last count is 0
# now checking step: 152.0
# One entire measurement is done, the last count is 0
# now checking step: 153.0
# One entire measurement is done, the last count is 0
# now checking step: 154.0
# One entire measurement is done, the last count is 0
# now checking step: 155.0
# One entire measurement is done, the last count is 0
# now checking step: 156.0
# One entire measurement is done, the last count is 0
# now checking step: 157.0
# One entire measurement is done, the last count is 0
# now checking step: 158.0
# One entire measurement is done, the last count is 0
# now checking step: 159.0
# One entire measurement is done, the last count is 0
# now checking step: 160.0
# One entire measurement is done, the last count is 0
# now checking step: 161.0
# One entire measurement is done, the last count is 0
# now checking step: 162.0
# One entire measurement is done, the last count is 0
# now checking step: 163.0
# One entire measurement is done, the last count is 0
# now checking step: 164.0
# One entire measurement is done, the last count is 0
# now checking step: 165.0
# One entire measurement is done, the last count is 0
# now checking step: 166.0
# One entire measurement is done, the last count is 0
# now checking step: 167.0
# One entire measurement is done, the last count is 0
# now checking step: 168.0
# One entire measurement is done, the last count is 0
# now checking step: 169.0
# One entire measurement is done, the last count is 0
# now checking step: 170.0
# One entire measurement is done, the last count is 0
# now checking step: 171.0
# One entire measurement is done, the last count is 0
# now checking step: 172.0
# One entire measurement is done, the last count is 0
# now checking step: 173.0
# One entire measurement is done, the last count is 0
# now checking step: 174.0
# One entire measurement is done, the last count is 0
# now checking step: 175.0
# One entire measurement is done, the last count is 0
# now checking step: 176.0
# One entire measurement is done, the last count is 0
# now checking step: 177.0
# One entire measurement is done, the last count is 0
# now checking step: 178.0
# One entire measurement is done, the last count is 0
# now checking step: 179.0
# One entire measurement is done, the last count is 0
# now checking step: 180.0
# One entire measurement is done, the last count is 0
# now checking step: 181.0
# One entire measurement is done, the last count is 0
# now checking step: 182.0
# One entire measurement is done, the last count is 0
# now checking step: 183.0
# One entire measurement is done, the last count is 0
# now checking step: 184.0
# One entire measurement is done, the last count is 0
# now checking step: 185.0
# One entire measurement is done, the last count is 0
# now checking step: 186.0
# One entire measurement is done, the last count is 0
# now checking step: 187.0
# One entire measurement is done, the last count is 0
# now checking step: 188.0
# One entire measurement is done, the last count is 0
# now checking step: 189.0
# One entire measurement is done, the last count is 0
# now checking step: 190.0
# One entire measurement is done, the last count is 0
# now checking step: 191.0
# One entire measurement is done, the last count is 0
# now checking step: 192.0
# One entire measurement is done, the last count is 0
# now checking step: 193.0
# One entire measurement is done, the last count is 0
# now checking step: 194.0
# One entire measurement is done, the last count is 0
# now checking step: 195.0
# One entire measurement is done, the last count is 0
# now checking step: 196.0
# One entire measurement is done, the last count is 0
# now checking step: 197.0
# One entire measurement is done, the last count is 0
# now checking step: 198.0
# One entire measurement is done, the last count is 0
# now checking step: 199.0
# One entire measurement is done, the last count is 0
# now checking step: 200.0
# One entire measurement is done, the last count is 0
# now checking step: 201.0
# One entire measurement is done, the last count is 0
# now checking step: 202.0
# One entire measurement is done, the last count is 0
# now checking step: 203.0
# One entire measurement is done, the last count is 0
# now checking step: 204.0
# One entire measurement is done, the last count is 0
# now checking step: 205.0
# One entire measurement is done, the last count is 0
# now checking step: 206.0
# One entire measurement is done, the last count is 0
# now checking step: 207.0
# One entire measurement is done, the last count is 0
# now checking step: 208.0
# One entire measurement is done, the last count is 0
# now checking step: 209.0
# One entire measurement is done, the last count is 0
# now checking step: 210.0
# One entire measurement is done, the last count is 0
# now checking step: 211.0
# One entire measurement is done, the last count is 0
# now checking step: 212.0
# One entire measurement is done, the last count is 0
# now checking step: 213.0
# One entire measurement is done, the last count is 0
# now checking step: 214.0
# One entire measurement is done, the last count is 0
# now checking step: 215.0
# One entire measurement is done, the last count is 0
# now checking step: 216.0
# One entire measurement is done, the last count is 0
# now checking step: 217.0
# One entire measurement is done, the last count is 0
# now checking step: 218.0
# One entire measurement is done, the last count is 0
# now checking step: 219.0
# One entire measurement is done, the last count is 0
# now checking step: 220.0
# One entire measurement is done, the last count is 0
# now checking step: 221.0
# One entire measurement is done, the last count is 0
# now checking step: 222.0
# One entire measurement is done, the last count is 0
# now checking step: 223.0
# One entire measurement is done, the last count is 0
# now checking step: 224.0
# One entire measurement is done, the last count is 0
# now checking step: 225.0
# One entire measurement is done, the last count is 0
# now checking step: 226.0
# One entire measurement is done, the last count is 0
# now checking step: 227.0
# One entire measurement is done, the last count is 0
# now checking step: 228.0
# One entire measurement is done, the last count is 0
# now checking step: 229.0
# One entire measurement is done, the last count is 1
# now checking step: 230.0
# One entire measurement is done, the last count is 0
# now checking step: 231.0
# One entire measurement is done, the last count is 0
# now checking step: 232.0
# One entire measurement is done, the last count is 0
# now checking step: 233.0
# One entire measurement is done, the last count is 0
# now checking step: 234.0
# One entire measurement is done, the last count is 0
# now checking step: 235.0
# One entire measurement is done, the last count is 0
# now checking step: 236.0
# One entire measurement is done, the last count is 0
# now checking step: 237.0
# One entire measurement is done, the last count is 0
# now checking step: 238.0
# One entire measurement is done, the last count is 0
# now checking step: 239.0
# One entire measurement is done, the last count is 0
# now checking step: 240.0
# One entire measurement is done, the last count is 1
# now checking step: 241.0
# One entire measurement is done, the last count is 0
# now checking step: 242.0
# One entire measurement is done, the last count is 0
# now checking step: 243.0
# One entire measurement is done, the last count is 0
# now checking step: 244.0
# One entire measurement is done, the last count is 0
# now checking step: 245.0
# One entire measurement is done, the last count is 0
# now checking step: 246.0
# One entire measurement is done, the last count is 0
# now checking step: 247.0
# One entire measurement is done, the last count is 0
# now checking step: 248.0
# One entire measurement is done, the last count is 0
# now checking step: 249.0
# One entire measurement is done, the last count is 0
# now checking step: 250.0
# One entire measurement is done, the last count is 0
# now checking step: 251.0
# One entire measurement is done, the last count is 0
# now checking step: 252.0
# One entire measurement is done, the last count is 0
# now checking step: 253.0
# One entire measurement is done, the last count is 2
# now checking step: 254.0
# One entire measurement is done, the last count is 0
# now checking step: 255.0
# One entire measurement is done, the last count is 0
# now checking step: 256.0
# One entire measurement is done, the last count is 0
# now checking step: 257.0
# One entire measurement is done, the last count is 0
# now checking step: 258.0
# One entire measurement is done, the last count is 0
# now checking step: 259.0
# One entire measurement is done, the last count is 0
# now checking step: 260.0
# One entire measurement is done, the last count is 0
# now checking step: 261.0
# One entire measurement is done, the last count is 0
# now checking step: 262.0
# One entire measurement is done, the last count is 0
# now checking step: 263.0
# One entire measurement is done, the last count is 0
# now checking step: 264.0
# One entire measurement is done, the last count is 0
# now checking step: 265.0
# One entire measurement is done, the last count is 1
# now checking step: 266.0
# One entire measurement is done, the last count is 0
# now checking step: 267.0
# One entire measurement is done, the last count is 1
# now checking step: 268.0
# One entire measurement is done, the last count is 0
# now checking step: 269.0
# One entire measurement is done, the last count is 0
# now checking step: 270.0
# One entire measurement is done, the last count is 0
# now checking step: 271.0
# One entire measurement is done, the last count is 0
# now checking step: 272.0
# One entire measurement is done, the last count is 0
# now checking step: 273.0
# One entire measurement is done, the last count is 0
# now checking step: 274.0
# One entire measurement is done, the last count is 1
# now checking step: 275.0
# One entire measurement is done, the last count is 2
# now checking step: 276.0
# One entire measurement is done, the last count is 0
# now checking step: 277.0
# One entire measurement is done, the last count is 1
# now checking step: 278.0
# One entire measurement is done, the last count is 2
# now checking step: 279.0
# One entire measurement is done, the last count is 1
# now checking step: 280.0
# One entire measurement is done, the last count is 1
# now checking step: 281.0
# One entire measurement is done, the last count is 0
# now checking step: 282.0
# One entire measurement is done, the last count is 0
# now checking step: 283.0
# One entire measurement is done, the last count is 1
# now checking step: 284.0
# One entire measurement is done, the last count is 0
# now checking step: 285.0
# One entire measurement is done, the last count is 0
# now checking step: 286.0
# One entire measurement is done, the last count is 0
# now checking step: 287.0
# One entire measurement is done, the last count is 0
# now checking step: 288.0
# One entire measurement is done, the last count is 2
# now checking step: 289.0
# One entire measurement is done, the last count is 0
# now checking step: 290.0
# One entire measurement is done, the last count is 6
# now checking step: 291.0
# One entire measurement is done, the last count is 1
# now checking step: 292.0
# One entire measurement is done, the last count is 6
# now checking step: 293.0
# One entire measurement is done, the last count is 3
# now checking step: 294.0
# One entire measurement is done, the last count is 2
# now checking step: 295.0
# One entire measurement is done, the last count is 7
# now checking step: 296.0
# One entire measurement is done, the last count is 2
# now checking step: 297.0
# One entire measurement is done, the last count is 3
# now checking step: 298.0
# One entire measurement is done, the last count is 3
# now checking step: 299.0
# One entire measurement is done, the last count is 1
# now checking step: 300.0
# One entire measurement is done, the last count is 3
# now checking step: 301.0
# One entire measurement is done, the last count is 1
# now checking step: 302.0
# One entire measurement is done, the last count is 1
# now checking step: 303.0
# One entire measurement is done, the last count is 0
# now checking step: 304.0
# One entire measurement is done, the last count is 0
# now checking step: 305.0
# One entire measurement is done, the last count is 1
# now checking step: 306.0
# One entire measurement is done, the last count is 0
# now checking step: 307.0
# One entire measurement is done, the last count is 0
# now checking step: 308.0
# One entire measurement is done, the last count is 0
# now checking step: 309.0
# One entire measurement is done, the last count is 0
# now checking step: 310.0
# One entire measurement is done, the last count is 1
# now checking step: 311.0
# One entire measurement is done, the last count is 0
# now checking step: 312.0
# One entire measurement is done, the last count is 0
# now checking step: 313.0
# One entire measurement is done, the last count is 2
# now checking step: 314.0
# One entire measurement is done, the last count is 1
# now checking step: 315.0
# One entire measurement is done, the last count is 0
# now checking step: 316.0
# One entire measurement is done, the last count is 0
# now checking step: 317.0
# One entire measurement is done, the last count is 0
# now checking step: 318.0
# One entire measurement is done, the last count is 0
# now checking step: 319.0
# One entire measurement is done, the last count is 0
# now checking step: 320.0
# One entire measurement is done, the last count is 0
# now checking step: 321.0
# One entire measurement is done, the last count is 0
# now checking step: 322.0
# One entire measurement is done, the last count is 0
# now checking step: 323.0
# One entire measurement is done, the last count is 0
# now checking step: 324.0
# One entire measurement is done, the last count is 0
# now checking step: 325.0
# One entire measurement is done, the last count is 0
# now checking step: 326.0
# One entire measurement is done, the last count is 0
# now checking step: 327.0
# One entire measurement is done, the last count is 0
# now checking step: 328.0
# One entire measurement is done, the last count is 0
# now checking step: 329.0
# One entire measurement is done, the last count is 0
# now checking step: 330.0
# One entire measurement is done, the last count is 0
# now checking step: 331.0
# One entire measurement is done, the last count is 0
# now checking step: 332.0
# One entire measurement is done, the last count is 0
# now checking step: 333.0
# One entire measurement is done, the last count is 0
# now checking step: 334.0
# One entire measurement is done, the last count is 1
# now checking step: 335.0
# One entire measurement is done, the last count is 0
# now checking step: 336.0
# One entire measurement is done, the last count is 0
# now checking step: 337.0
# One entire measurement is done, the last count is 0
# now checking step: 338.0
# One entire measurement is done, the last count is 0
# now checking step: 339.0
# One entire measurement is done, the last count is 0
# now checking step: 340.0
# One entire measurement is done, the last count is 0
# now checking step: 341.0
# One entire measurement is done, the last count is 0
# now checking step: 342.0
# One entire measurement is done, the last count is 0
# now checking step: 343.0
# One entire measurement is done, the last count is 0
# now checking step: 344.0
# One entire measurement is done, the last count is 0
# now checking step: 345.0
# One entire measurement is done, the last count is 0
# now checking step: 346.0
# One entire measurement is done, the last count is 0
# now checking step: 347.0
# One entire measurement is done, the last count is 0
# now checking step: 348.0
# One entire measurement is done, the last count is 0
# now checking step: 349.0
# One entire measurement is done, the last count is 0
# now checking step: 350.0
# One entire measurement is done, the last count is 0
# now checking step: 351.0
# One entire measurement is done, the last count is 0
# now checking step: 352.0
# One entire measurement is done, the last count is 0
# now checking step: 353.0
# One entire measurement is done, the last count is 0
# now checking step: 354.0
# One entire measurement is done, the last count is 0
# now checking step: 355.0
# One entire measurement is done, the last count is 0
# now checking step: 356.0
# One entire measurement is done, the last count is 0
# now checking step: 357.0
# One entire measurement is done, the last count is 0
# now checking step: 358.0
# One entire measurement is done, the last count is 0
# now checking step: 359.0
# One entire measurement is done, the last count is 0
# now checking step: 360.0
# One entire measurement is done, the last count is 0
# now checking step: 361.0
# One entire measurement is done, the last count is 0
# now checking step: 362.0
# One entire measurement is done, the last count is 0
# now checking step: 363.0
# One entire measurement is done, the last count is 0
# now checking step: 364.0
# One entire measurement is done, the last count is 0
# now checking step: 365.0
# One entire measurement is done, the last count is 0
# now checking step: 366.0
# One entire measurement is done, the last count is 0
# now checking step: 367.0
# One entire measurement is done, the last count is 0
# now checking step: 368.0
# One entire measurement is done, the last count is 0
# now checking step: 369.0
# One entire measurement is done, the last count is 0
# now checking step: 370.0
# One entire measurement is done, the last count is 0
# now checking step: 371.0
# One entire measurement is done, the last count is 0
# now checking step: 372.0
# One entire measurement is done, the last count is 0
# now checking step: 373.0
# One entire measurement is done, the last count is 0
# now checking step: 374.0
# One entire measurement is done, the last count is 0
# now checking step: 375.0
# One entire measurement is done, the last count is 0
# now checking step: 376.0
# One entire measurement is done, the last count is 0
# now checking step: 377.0
# One entire measurement is done, the last count is 0
# now checking step: 378.0
# One entire measurement is done, the last count is 0
# now checking step: 379.0
# One entire measurement is done, the last count is 0
# now checking step: 380.0
# One entire measurement is done, the last count is 0
# now checking step: 381.0
# One entire measurement is done, the last count is 0
# now checking step: 382.0
# One entire measurement is done, the last count is 0
# now checking step: 383.0
# One entire measurement is done, the last count is 0
# now checking step: 384.0
# One entire measurement is done, the last count is 0
# now checking step: 385.0
# One entire measurement is done, the last count is 0
# now checking step: 386.0
# One entire measurement is done, the last count is 0
# now checking step: 387.0
# One entire measurement is done, the last count is 0
# now checking step: 388.0
# One entire measurement is done, the last count is 0
# now checking step: 389.0
# One entire measurement is done, the last count is 0
# now checking step: 390.0
# One entire measurement is done, the last count is 0
# now checking step: 391.0
# One entire measurement is done, the last count is 0
# now checking step: 392.0
# One entire measurement is done, the last count is 0
# now checking step: 393.0
# One entire measurement is done, the last count is 0
# now checking step: 394.0
# One entire measurement is done, the last count is 0
# now checking step: 395.0
# One entire measurement is done, the last count is 0
# now checking step: 396.0
# One entire measurement is done, the last count is 0
# now checking step: 397.0
# One entire measurement is done, the last count is 0
# now checking step: 398.0
# One entire measurement is done, the last count is 0
# now checking step: 399.0
# One entire measurement is done, the last count is 0
# 106.24518275260925

# %%
ps.Plot2D(x = x_list*stride, y = T, Z = results, xlabel = "stepper motor position", ylabel = "cycle duration", zlabel = "average number of counts")

# %% [markdown]
# ## 2D

# %%
center = 3360
stride = 1
half_width = 200


# scan list gneration
x_list = np.arange(2* half_width/stride)

# %%
start_position = center - half_width

v_list = np.linspace(-1,1,11)
stark_map = []
for v in v_list:
    mcbox.set_voltage_1chan(board_num = 0, channel = 10, voltage = v, bipolar = True)
    mcbox.set_voltage_1chan(board_num = 0, channel = 11, voltage = -v, bipolar = True)
    
    # everytime go further and go back to release the band tension and gear margin
    weeder.move(header = "A", position = start_position-100)
    weeder.move(header = "A", position = start_position)
    results = []
    for idx in x_list:
        print(f"now checking step: {idx}", end = "\r", flush=True)
        sr400.count_reset()
        time.sleep(0.005)
        result = np.mean(sr400.read_entire_counts(counter="A",length = cycle_number))
        results.append(result)
        for i in range(stride):
            weeder.step("A","+")
        time.sleep(0.005)
    stark_map.append(results)
# Out:
# Channel 10 has been set to -1.0 V.
# Channel 11 has been set to 1.0 V.
# start at 3423 --> 3060.0 --> 3060
# Old position: 3423
# New position: 3061
# start at 3061 --> 3160.0 --> 3160
# Old position: 3061
# New position: 3160
# Channel 10 has been set to -0.8 V.
# Channel 11 has been set to 0.8 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to -0.6 V.
# Channel 11 has been set to 0.6 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to -0.3999999999999999 V.
# Channel 11 has been set to 0.3999999999999999 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to -0.19999999999999996 V.
# Channel 11 has been set to 0.19999999999999996 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 0.0 V.
# Channel 11 has been set to -0.0 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 0.20000000000000018 V.
# Channel 11 has been set to -0.20000000000000018 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 0.40000000000000013 V.
# Channel 11 has been set to -0.40000000000000013 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 0.6000000000000001 V.
# Channel 11 has been set to -0.6000000000000001 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 0.8 V.
# Channel 11 has been set to -0.8 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# Channel 10 has been set to 1.0 V.
# Channel 11 has been set to -1.0 V.
# start at 3560 --> 3060.0 --> 3060
# Old position: 3560
# New position: 3060
# start at 3060 --> 3160.0 --> 3160
# Old position: 3060
# New position: 3160
# now checking step: 399.0

# %%
mcbox.set_voltage_1chan(board_num = 0, channel = 11, voltage = 0, bipolar = True)
# Out:
# Channel 11 has been set to 0 V.

# %%
ps.Plot3D(x = x_list*stride, y = v_list, Z = stark_map, xlabel = "stepper motor position", ylabel = "x voltage (V)", zlabel = "average number of counts")

# %%
ps.Plot3D(x = v_list , y = x_list*stride, Z = np.array(stark_map).T, xlabel = "x voltage (V)", ylabel = "stepper motor position", zlabel = "average number of counts")
