# %%
from Equipments import Weeder
import numpy as np
import pyvisa
import time

# %%
rm = pyvisa.ResourceManager()
print(rm.list_resources())
# Out:
# ('ASRL1::INSTR', 'ASRL2::INSTR', 'ASRL3::INSTR', 'ASRL4::INSTR', 'ASRL5::INSTR', 'ASRL6::INSTR', 'ASRL7::INSTR')

# %%
weeder = Weeder.Weeder("ASRL1::INSTR")

# %%
weeder.position(header = "A", query = True)
# Out:
# 'A4000'

# %% [markdown]
# # echo test

# %%
weeder.pyvisa.write("A" + "M" + str(3000) + "\r")
# Out:
# 9

# %%
weeder.pyvisa.read("\r")
# Out:
# 'AM3000'

# %%
weeder.step("A","-")
# Out:
# 'AS-'

# %% [markdown]
# # speed test (move 1000 steps)

# %% [markdown]
# ## move

# %%
s = time.time()
weeder.pyvisa.write("A" + "M" + str(4000) + "\r")
e = time.time()
print(e-s)
# Out:
# 9

# %% [markdown]
# ## step iteration

# %%
s = time.time()
for i in range(1000):
    weeder.step("A","+")
e = time.time()
print(e-s)
# Out:
# 16.178519010543823

# %%
# np.sign(-10)
# Out:
# -1

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
a = -1
print(1 if a > 0 else -1)
# Out:
# -1

# %%
print("Hello world!",end= "\r",flush= True)
print("Hello world!",end= "\r",flush= True)
print("Hello world!",end= "\r",flush= True)
# Out:
# Hello world!
