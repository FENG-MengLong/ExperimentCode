# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s2 = np.linspace(10,200,200)
f=8
d = f+s2*f/(s2-f)

# %%
plt.plot(s2,d)

# %%
s2 = np.linspace(130,500,200)
f=8
d = f+s2*f/(s2-f)
plt.plot(s2,d)
