# %%
from DataProcessing import Readout
import matplotlib.pyplot as plt
from matplotlib import rcParams
import lmfit

rcParams['font.family'] = 'Times New Roman'
rcParams['mathtext.fontset'] = 'stix'
rcParams['axes.unicode_minus'] = False
rcParams.update({
	'font.size': 14,
	'axes.titlesize': 14,
	'axes.labelsize': 14,
	'xtick.labelsize': 14,
	'ytick.labelsize': 14,
	'legend.fontsize': 14,
	'figure.titlesize': 14,
	'legend.frameon': False,
})

# %%
root_dir = "X:/migratedData/Rydberg_QIS/data"
x,y,z,notes = Readout.read_saved_csv_by_id(root_dir=root_dir, date="2025/12/02", plot_id=16)

# %%
plt.pcolormesh(x,y,z.T)
plt.xlabel(notes["xlabel"])
plt.ylabel(notes["ylabel"])
cbar = plt.colorbar()
cbar.set_label(notes["zlabel"])

# %%
print(notes)
# Out:
# {'Date': '2025/12/02', 'ID': '16', 'Data hash': '30b0251976d991f8071c7a01733f77c0ca8ee6134f051b01bf9bb6646d81c007', 'xlabel': 'x voltage (V)', 'ylabel': 'frequency (kHz)', 'zlabel': 'average number of counts', 'x range': '-1.0 to 1.0, total 11 points', 'y range': '0.0 to 51471.0, total 400 points', 'Notes': {'gate_width': '1.5e-05', 'gate_delay': '3e-06', 'bnc575 T0': '1.00e-03', 'bnc575 pulses': "[['A', 0.0009, 0, 'TTL'], ['B', 1e-05, 0.000905, 15], ['C', 1e-05, 0.000905, 'TTL'], ['D', 2e-05, 0.000915, 8]]"}}
