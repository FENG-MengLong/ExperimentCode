# %%
from pylablib.devices import Andor

# %%
Andor.get_cameras_number_SDK2()
# Out:
# 1

# %%
cam1 = Andor.AndorSDK2Camera(idx=0,temperature=-50, fan_mode="off")
# Out:
# please test
# set,get shutter

# %%
cam1.close()

# %%
cam1.get_accum_mode_parameters()
# Out:
# (1, 0)

# %%
cam1.setup_accum_mode(1)
# Out:
# (1, 0)

# %%
cam1.start_acquisition()
a = cam1.read_newest_image()
# Out:
# ---------------------------------------------------------------------------
# AndorSDK2LibError                         Traceback (most recent call last)
# File ~\Documents\Python\CodeTest\pylablib\devices\Andor\AndorSDK2.py:1128, in AndorSDK2Camera.get_new_images_range(self)
#    1127 try:
# -> 1128     rng=lib.GetNumberNewImages()
#    1129     return (rng[0]-1,rng[1]-1)
#
# File <string>:1, in <lambda>()
#
# File ~\Documents\Python\CodeTest\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#
# File ~\Documents\Python\CodeTest\pylablib\devices\Andor\atmcd32d_lib.py:41, in errcheck.<locals>.errchecker(result, func, arguments)
#      40 if result not in passing:
# ...

# %%
print(a)
# Out:
# None

# %%
a = cam1.snap()

# %%
print(a)
# Out:
# None

# %%
cam1.get_acquisition_mode()
# Out:
# 'single'

# %%
cam1.set_acquisition_mode("single")
cam1.set_exposure(0.1)
# Out:
# 0.10000000149011612

# %%
cam1.get_temperature()
# Out:
# -37.71099853515625

# %%
cam1.get_temperature_setpoint()
# Out:
# -50

# %%
cam1.get_temperature_status()
# Out:
# 'not_reached'

# %%
cam1.set_shutter("open")
# Out:
# ('open', 0, 0, 0)

# %%
cam1.get_shutter()
# Out:
# 'open'

# %%
cam1.get_readout_time()
# Out:
# 0.03219030052423477

# %%
cam1.get_read_mode()
# Out:
# 'image'

# %%
cam1.get_image_mode_parameters()
# Out:
# (0, 512, 0, 512, 1, 1)

# %%
trng = cam1.get_temperature_range()
# cam1.get_temperature()
# print(cam1.get_temperature_status())
trng[0]+int((trng[1]-trng[0])*0.2)
# Out:
# -76

# %%
pip install pyAndorSDK2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyAndorSDK2 (from versions: none)
# ERROR: No matching distribution found for pyAndorSDK2

# %%
import os
os.add_dll_directory(r"C:\Program Files\Andor SDK")
# Out:
# <AddedDllDirectory('C:\\Program Files\\Andor SDK')>
